# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
db = pd.read_csv("nba_shotchartdetail_2018-19.csv")
db.head()
# Out:
#            GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID       PLAYER_NAME  \
# 0  Shot Chart Detail  21800001              7     203496  Robert Covington
# 1  Shot Chart Detail  21800001             10    1628369      Jayson Tatum
# 2  Shot Chart Detail  21800001             14    1627759      Jaylen Brown
# 3  Shot Chart Detail  21800001             17     203954       Joel Embiid
# 4  Shot Chart Detail  21800001             19    1628369      Jayson Tatum
#
#       TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612755  Philadelphia 76ers       1                 11
# 1  1610612738      Boston Celtics       1                 11
# 2  1610612738      Boston Celtics       1                 11
# 3  1610612755  Philadelphia 76ers       1                 10
# 4  1610612738      Boston Celtics       1                 10
#
#    SECONDS_REMAINING  ...        SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                 40  ...             Center(C)          24+ ft.
# 1                 15  ...  Left Side Center(LC)          24+ ft.
# 2                  3  ...             Center(C)  Less Than 8 ft.
# 3                 55  ...             Center(C)  Less Than 8 ft.
# 4                 36  ...             Center(C)  Less Than 8 ft.
#
#   SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0            26   -53   264                   1               0   20181016
# 1            25  -148   207                   1               0   20181016
# 2             1     4    18                   1               0   20181016
# 3             0    -8     3                   1               1   20181016
# 4             4   -46     1                   1               0   20181016
#
#    HTM  VTM
# 0  BOS  PHI
# 1  BOS  PHI
# 2  BOS  PHI
# 3  BOS  PHI
# 4  BOS  PHI
#
# [5 rows x 24 columns]

# %%
db = db.drop(["GRID_TYPE", "GAME_EVENT_ID", "TEAM_ID", "SHOT_ATTEMPTED_FLAG"],1)
db.head()
# Out:
# C:\Users\Florian\AppData\Local\Temp/ipykernel_15560/1091249216.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   db = db.drop(["GRID_TYPE", "GAME_EVENT_ID", "TEAM_ID", "SHOT_ATTEMPTED_FLAG"],1)
#     GAME_ID  PLAYER_ID       PLAYER_NAME           TEAM_NAME  PERIOD  \
# 0  21800001     203496  Robert Covington  Philadelphia 76ers       1
# 1  21800001    1628369      Jayson Tatum      Boston Celtics       1
# 2  21800001    1627759      Jaylen Brown      Boston Celtics       1
# 3  21800001     203954       Joel Embiid  Philadelphia 76ers       1
# 4  21800001    1628369      Jayson Tatum      Boston Celtics       1
#
#    MINUTES_REMAINING  SECONDS_REMAINING   EVENT_TYPE         ACTION_TYPE  \
# 0                 11                 40  Missed Shot           Jump Shot
# 1                 11                 15  Missed Shot           Jump Shot
# 2                 11                  3  Missed Shot  Running Layup Shot
# 3                 10                 55    Made Shot  Running Layup Shot
# 4                 10                 36  Missed Shot  Driving Layup Shot
#
#         SHOT_TYPE        SHOT_ZONE_BASIC        SHOT_ZONE_AREA  \
# 0  3PT Field Goal      Above the Break 3             Center(C)
# 1  3PT Field Goal      Above the Break 3  Left Side Center(LC)
# 2  2PT Field Goal        Restricted Area             Center(C)
# 3  2PT Field Goal        Restricted Area             Center(C)
# 4  2PT Field Goal  In The Paint (Non-RA)             Center(C)
#
#    SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_MADE_FLAG  GAME_DATE  \
# 0          24+ ft.             26    -53    264               0   20181016
# 1          24+ ft.             25   -148    207               0   20181016
# 2  Less Than 8 ft.              1      4     18               0   20181016
# 3  Less Than 8 ft.              0     -8      3               1   20181016
# 4  Less Than 8 ft.              4    -46      1               0   20181016
#
#    HTM  VTM
# 0  BOS  PHI
# 1  BOS  PHI
# 2  BOS  PHI
# 3  BOS  PHI
# 4  BOS  PHI

# %%
def hit():   
    return db[db["SHOT_MADE_FLAG"] == "1"]

def actiontype(actiontype):
    return db[db["ACTION_TYPE"] == actiontype]

def hitrate(playername):
    a = db[db['PLAYER_NAME'] == playername]
    b = a[a['SHOT_MADE_FLAG'] == "1"]
    a = int(a)
    b = int(b)
    hr = len(b) / len(a)
    return hr

hitrate("Jayson Tatum")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15560/2023449940.py in <module>
#      13     return hr
#      14
# ---> 15 hitrate("Jayson Tatum")
#
# ~\AppData\Local\Temp/ipykernel_15560/2023449940.py in hitrate(playername)
#       8     a = db[db['PLAYER_NAME'] == playername]
#       9     b = a[a['SHOT_MADE_FLAG'] == "1"]
# ---> 10     a = int(a)
#      11     b = int(b)
#      12     hr = len(b) / len(a)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'DataFrame'

# %%
db[db['PLAYER_NAME'] == "Jayson Tatum"]
# Out:
#          GAME_ID  PLAYER_ID   PLAYER_NAME       TEAM_NAME  PERIOD  \
# 1       21800001    1628369  Jayson Tatum  Boston Celtics       1
# 4       21800001    1628369  Jayson Tatum  Boston Celtics       1
# 12      21800001    1628369  Jayson Tatum  Boston Celtics       1
# 20      21800001    1628369  Jayson Tatum  Boston Celtics       1
# 25      21800001    1628369  Jayson Tatum  Boston Celtics       1
# ...          ...        ...           ...             ...     ...
# 210815  21801183    1628369  Jayson Tatum  Boston Celtics       4
# 210823  21801183    1628369  Jayson Tatum  Boston Celtics       4
# 210825  21801183    1628369  Jayson Tatum  Boston Celtics       4
# 214333  21801203    1628369  Jayson Tatum  Boston Celtics       1
# 214336  21801203    1628369  Jayson Tatum  Boston Celtics       1
#
#         MINUTES_REMAINING  SECONDS_REMAINING   EVENT_TYPE  \
# 1                      11                 15  Missed Shot
# 4                      10                 36  Missed Shot
# 12                      9                 19    Made Shot
# 20                      7                 26    Made Shot
# 25                      6                 10    Made Shot
# ...                   ...                ...          ...
# 210815                  6                 49  Missed Shot
# 210823                  4                 45    Made Shot
# 210825                  4                 25  Missed Shot
# 214333                  8                  4  Missed Shot
# 214336                  7                 26  Missed Shot
#
#                 ACTION_TYPE       SHOT_TYPE        SHOT_ZONE_BASIC  \
# 1                 Jump Shot  3PT Field Goal      Above the Break 3
# 4        Driving Layup Shot  2PT Field Goal  In The Paint (Non-RA)
# 12         Pullup Jump shot  2PT Field Goal  In The Paint (Non-RA)
# 20      Step Back Jump shot  3PT Field Goal          Left Corner 3
# 25         Pullup Jump shot  2PT Field Goal              Mid-Range
# ...                     ...             ...                    ...
# 210815            Jump Shot  3PT Field Goal          Left Corner 3
# 210823  Step Back Jump shot  2PT Field Goal              Mid-Range
# 210825     Pullup Jump shot  3PT Field Goal      Above the Break 3
# 214333   Driving Layup Shot  2PT Field Goal  In The Paint (Non-RA)
# 214336            Jump Shot  2PT Field Goal              Mid-Range
#
#               SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  \
# 1       Left Side Center(LC)          24+ ft.             25   -148    207
# 4                  Center(C)  Less Than 8 ft.              4    -46      1
# 12                 Center(C)         8-16 ft.             15    -63    138
# 20              Left Side(L)          24+ ft.             24   -240     50
# 25                 Center(C)        16-24 ft.             18    -44    183
# ...                      ...              ...            ...    ...    ...
# 210815          Left Side(L)          24+ ft.             23   -232    -34
# 210823          Left Side(L)         8-16 ft.             15   -130     79
# 210825  Left Side Center(LC)          24+ ft.             24   -173    179
# 214333             Center(C)  Less Than 8 ft.              7    -44     63
# 214336             Center(C)         8-16 ft.             15     49    146
#
#         SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 1                    0   20181016  BOS  PHI
# 4                    0   20181016  BOS  PHI
# 12                   1   20181016  BOS  PHI
# 20                   1   20181016  BOS  PHI
# 25                   1   20181016  BOS  PHI
# ...                ...        ...  ...  ...
# 210815               0   20190405  IND  BOS
# 210823               1   20190405  IND  BOS
# 210825               0   20190405  IND  BOS
# 214333               0   20190407  BOS  ORL
# 214336               0   20190407  BOS  ORL
#
# [1036 rows x 20 columns]
